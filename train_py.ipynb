# %% [markdown]
# <a href="https://colab.research.google.com/github/nguangadonel-hue/Data-Mining-Projet/blob/main/train_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git remote -v
# Out:
# fatal: not a git repository (or any of the parent directories): .git
